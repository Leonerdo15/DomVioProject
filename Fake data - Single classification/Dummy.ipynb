# %% [markdown]
# # SVM
#
# ### Data Preparation

# %%
import pandas as pd

# Load the digits dataset
data = pd.read_csv('data/IPV_perpetration_study_replicated.csv')
data
# Out:
#      Age  Exchange_Sex  Children  Suicide_Attempt  Homeless_Age  Jail  \
# 0     20             0         0                0            18     0
# 1     23             0         1                0            12     0
# 2     23             0         1                0            14     0
# 3     17             0         0                0            21     0
# 4     21             0         0                0            13     0
# ..   ...           ...       ...              ...           ...   ...
# 348   20             0         0                0            12     1
# 349   24             0         0                0            21     0
# 350   20             1         0                0            21     0
# 351   20             1         0                1            18     0
# 352   24             0         0                0            19     0
#
#      Juggalo  Male  LGBQ  White  ...  Community_Violence  Sexual_Abuse  \
# ...

# %% [markdown]
# ##

# %%
### Data Preparation

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier

# Split the data into features and target label Age
x = data[["Age", "Exchange_Sex", "Children", "Suicide_Attempt", "Homeless_Age", "Jail", "Juggalo", "Male", "LGBQ", "White", "Literal_Homeless", "Weapon", "Violence", "Gang", "PTSD", "Depressed", "Community_Violence", "Sexual_Abuse", "Lonely_1", "Lonely_2", "Lonely_3", "Hard_Drug_Use", "Foster_Care", "Job"]]
y = data["IPV_Perpetration"]

SEED = 0
np.random.seed(SEED)
raw_train_x, raw_test_x, train_y, test_y = train_test_split(x, y, test_size = 0.30,
                                                              stratify = y)

scaler = StandardScaler()
scaler.fit(raw_train_x)
train_x = scaler.transform(raw_train_x)
test_x = scaler.transform(raw_test_x)



dummy = DummyClassifier()
dummy.fit(train_x, train_y)
accuracy = dummy.score(test_x, test_y) * 100
print(f"The accuracy was {accuracy:.2f}%")
# Out:
# The accuracy was 69.81%
